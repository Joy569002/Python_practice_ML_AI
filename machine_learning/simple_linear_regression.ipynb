# %%
import matplotlib.pyplot as plt
import numpy as np
import  matplotlib.pyplot as pit
import pandas as pd
import os
print(os.getcwd())
# Out:
# C:\Users\Tanjim\PycharmProjects\PythonProject\machine_learning

# %%
csv_file_name="Salary_Data.csv"
dataset=pd.read_csv(csv_file_name)
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %% [markdown]
# VisualZing the training set

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title("cgpa vs salary")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()

# %% [markdown]
# We have linear dataset

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title("cgpa vs salary(test set)")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()
